# %%
#json
import random
from kivy.storage.jsonstore import JsonStore
from kivy.uix.boxlayout import BoxLayout
from kivy.app import App
#kivy.require("1.9.0")
from kivy.lang import Builder
from kivy.uix.screenmanager import ScreenManager, Screen, FadeTransition
from kivy.uix.widget import Widget
from kivy.graphics import Line
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.uix.scrollview import ScrollView 
from kivy.properties import StringProperty 
from kivy.properties import ObjectProperty 
from kivy.uix.recycleview import RecycleView
from kivy.uix.button import Button
from gtts import gTTs




#store = JsonStore('A1deutsch.json')
class ScreenManagement(ScreenManager):
    MY_GLOBAL = '1'
    SCREEN = ''
    
    pass

class IntroScreen(Screen):
    pass                           

class IndexScreen(Screen):
    pass

class VerbosScreen(Screen):
    def __init__(self, **kwargs):
        super(VerbosScreen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION Verben')['Al']
        self.Es = JsonStore("A1deutsch.json").get('LEKTION Verben')['Es']

    def change(self):
        ScreenManagement.MY_GLOBAL = 'Verben'
        ScreenManagement.SCREEN = 'Verben'
    


class L1Screen(Screen):
    def __init__(self, **kwargs):
        super(L1Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 1')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 1')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        GameScreen.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        GameScreen.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')


    pass        
class L2Screen(Screen):
    def __init__(self, **kwargs):
        super(L2Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 2')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 2')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '2'
        ScreenManagement.SCREEN = 'L2'
    pass  
class L3Screen(Screen):
    def __init__(self, **kwargs):
        super(L3Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 3')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 3')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '3'
        ScreenManagement.SCREEN = 'L3'

    pass
class L4Screen(Screen):
    def __init__(self, **kwargs):
        super(L4Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 4')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 4')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '4'
        ScreenManagement.SCREEN = 'L4'

    pass
class L5Screen(Screen):
    def __init__(self, **kwargs):
        super(L5Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 5')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 5')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '5'
        ScreenManagement.SCREEN = 'L5'

    pass
class L6Screen(Screen):
    def __init__(self, **kwargs):
        super(L6Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 6')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 6')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '6'
        ScreenManagement.SCREEN = 'L6'

    pass
class L7Screen(Screen):
    def __init__(self, **kwargs):
        super(L7Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 7')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 7')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '7'
        ScreenManagement.SCREEN = 'L7'

    pass
class L8Screen(Screen):
    def __init__(self, **kwargs):
        super(L8Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 8')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 8')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '8'
        ScreenManagement.SCREEN = 'L8'

    pass
class L9Screen(Screen):
    def __init__(self, **kwargs):
        super(L9Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 9')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 9')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '9'
        ScreenManagement.SCREEN = 'L9'

    pass
class L10Screen(Screen):
    def __init__(self, **kwargs):
        super(L10Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 10')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 10')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '10'
        ScreenManagement.SCREEN = 'L10'
    pass
class L11Screen(Screen):
    def __init__(self, **kwargs):
        super(L11Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 11')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 11')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '11'
        ScreenManagement.SCREEN = 'L11'
    pass
class L12Screen(Screen):
    def __init__(self, **kwargs):
        super(L12Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 12')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 12')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '12'
        ScreenManagement.SCREEN = 'L12'
    pass
class L13Screen(Screen):
    def __init__(self, **kwargs):
        super(L13Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 13')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 13')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '13'
        ScreenManagement.SCREEN = 'L13'
    pass
class L14Screen(Screen):
    def __init__(self, **kwargs):
        super(L14Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 14')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 14')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '14'
        ScreenManagement.SCREEN = 'L14'
    pass
class L15Screen(Screen):
    def __init__(self, **kwargs):
        super(L15Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 15')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 15')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '15'
        ScreenManagement.SCREEN = 'L15'
        
    pass
class L16Screen(Screen):
    def __init__(self, **kwargs):
        super(L16Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 16')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 16')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '16'
        ScreenManagement.SCREEN = 'L16'
    pass
class L17Screen(Screen):
    def __init__(self, **kwargs):
        super(L17Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 17')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 17')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '17'
        ScreenManagement.SCREEN = 'L17'
    pass
class L18Screen(Screen):
    def __init__(self, **kwargs):
        super(L18Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 18')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 18')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '18'
        ScreenManagement.SCREEN = 'L18'
    pass
class L19Screen(Screen):
    def __init__(self, **kwargs):
        super(L19Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 19')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 19')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '19'
        ScreenManagement.SCREEN = 'L19'
    pass
class L20Screen(Screen):
    def __init__(self, **kwargs):
        super(L20Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 20')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 20')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '20'
        ScreenManagement.SCREEN = 'L20'
    pass
class L21Screen(Screen):
    def __init__(self, **kwargs):
        super(L21Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 21')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 21')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '21'
        ScreenManagement.SCREEN = 'L21'
    pass
class L22Screen(Screen):
    def __init__(self, **kwargs):
        super(L22Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 22')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 22')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '22'
        ScreenManagement.SCREEN = 'L22'
    pass
class L23Screen(Screen):
    def __init__(self, **kwargs):
        super(L23Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 23')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 23')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '23'
        ScreenManagement.SCREEN = 'L23'
    pass
class L24Screen(Screen):
    def __init__(self, **kwargs):
        super(L24Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 24')['Al'].replace("\\n","\n")
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 24')['Es'].replace("\\n","\n")
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '24'
        ScreenManagement.SCREEN = 'L24'
    pass





    

class GameScreen(Screen):
    def __init__(self, **kwargs):
        super(GameScreen, self).__init__(**kwargs)
        App.get_running_app()
        
        self.num = random.choice(range(4))
        self.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.randnum = random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution)))
        
    
    
    
    
    
    
    
    
    def on_click0(self):
        try:
            if self.solution.index(self.ids.btn0.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn0.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn0.background_normal = 'normal.png'
                self.ids.btn0.background_down = 'down.png'
            else:
                self.ids.btn0.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn0.text = self.ids.btn0.text
            
    def on_click1(self):
        try:
            if self.solution.index(self.ids.btn1.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn1.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn1.background_normal = 'normal.png'
                self.ids.btn1.background_down = 'down.png'
            else:
                self.ids.btn1.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn1.text = self.ids.btn1.text
            
    def on_click2(self):
        try:
            if self.solution.index(self.ids.btn2.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn2.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn2.background_normal = 'normal.png'
                self.ids.btn2.background_down = 'down.png'
            else:
                self.ids.btn2.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn2.text = self.ids.btn2.text
            
    def on_click3(self):
        try:
            if self.solution.index(self.ids.btn3.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn3.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn3.background_normal = 'normal.png'
                self.ids.btn3.background_down = 'down.png'
            else:
                self.ids.btn3.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn3.text = self.ids.btn3.text
            
    def refres(self):
        self.num = random.choice(range(4))
        self.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.randnum = random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution)))
        self.ids.btn.text = '[i]'+self.test[self.randnum[self.num]]+'[/i]'
        self.ids.btn0.text = '[i]'+self.solution[self.randnum[0]]+'[/i]'
        self.ids.btn1.text = '[i]'+self.solution[self.randnum[1]]+'[/i]'
        self.ids.btn2.text = '[i]'+self.solution[self.randnum[2]]+'[/i]'
        self.ids.btn3.text = '[i]'+self.solution[self.randnum[3]]+'[/i]'
        self.ids.btn3.background_normal = 'down.png'
        self.ids.btn3.background_down = 'normal.png'
        self.ids.btn2.background_normal = 'down.png'
        self.ids.btn2.background_down = 'normal.png'
        self.ids.btn1.background_normal = 'down.png'
        self.ids.btn1.background_down = 'normal.png'
        self.ids.btn0.background_normal = 'down.png'
        self.ids.btn0.background_down = 'normal.png'






        
class RV(RecycleView):
    def __init__(self,**kwargs):
        super(RV,self).__init__(**kwargs)
        self.verb = JsonStore("Verbos1.json").get('A1')['verb']
        
        


        
      
        
class ScrollableLabel(ScrollView): 
    text = StringProperty('') 



presentation = Builder.load_string('''
#: import FadeTransition kivy.uix.screenmanager.FadeTransition


<Button>:
    
    font_size: 50
	color: 0,0,0,1
	size_hint: 0.2, 0.1
    markup: True
    background_down: 'normal.png'
    background_normal: 'down.png'
    border: 30,30,30,30
    pos_hint: {"right":1, "top":0.1}
    
    
<RV>:
    viewclass: 'PageLabel'
    data:[{'text': str('[i]'+x+'[/i]')} for x in root.verb]
    RecycleGridLayout:
        cols:2
        default_size: dp(90), dp(56)
        default_size_hint: 1, None
        size_hint_y: None
        
        width:self.minimum_width
        height: self.minimum_height
        

    
    
<GameButton@Button>:
    
    font_size: 60
	color: 0,0,0,1
    markup: True
	size_hint: 0.2, 0.1
    background_down: 'normal.png'
    background_normal: 'down.png'
    border: 30,30,30,30
    

<MainButton@Button>:
    
    font_size: 80
	color: 0,0,0,1
    markup: True
	size_hint: 0.2, 0.1
    background_down: 'normal.png'
    background_normal: 'down.png'
    border: 30,30,30,30
    
<IndexButton@Button>:

    markup: True
    background_normal: ''
    background_color: 1, 1, 1, 1
    font_size: 50
    
    
   
<PageBoxLayout@BoxLayout>:
    
    size_hint: (None, None)
    height: self.minimum_height
    padding: 30,30,30,30
    
    
<PageLabel@Label>:
    
    size_hint_y: None
    size_hint_x: 1
    height: self.texture_size[1]
    text_size: (self.width, None)
    color: 0,0,0,1
    markup: True
    padding: (0, 10)
    
    

    
    
ScreenManagement:
	transition: FadeTransition()
    IntroScreen:
	
    IndexScreen:
    VerbosScreen:
    L1Screen:
    L2Screen:
    L3Screen:
    L4Screen:
    L5Screen:
    L6Screen:
    L7Screen:
    L8Screen:
    L9Screen:
    L10Screen:
    L11Screen:
    L12Screen:
    L13Screen:
    L14Screen:
    L15Screen:
    L16Screen:
    L17Screen:
    L18Screen:
    L19Screen:
    L20Screen:
    L21Screen:
    L22Screen:
    L23Screen:
    L24Screen:
    GameScreen:
    

    
<IntroScreen>:
	name: "Intro"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size
            
	FloatLayout:
		Button:      
			text: "[i]Start[/i]"
			on_release: app.root.current = "Index" 

                        
		Label:
            font_size: 180
            markup: True
			text: "[i]     C2\\nDeutsch\\n     A1[/i]"
			pos_hint: {"right":0.65, "top":0.65}
	        color: 1,0.55,0,1
            size_hint: 0.3, 0.3
            
            
            

<IndexScreen>:
	name: "Index"
    canvas.before:
        Color:
            rgba: 1, 0.55, 0, 1
        Rectangle:
            pos: self.pos
            size: self.size
    BoxLayout:
        orientation: "vertical"
    

        GridLayout:
            orientation: "vertical"
            size_hint_y: 1
            padding: 20,20,20,20
            height: self.minimum_height\n
            row_default_height: 60
            cols:3
            
                
            IndexButton:
                
                text:"[color=1874cd][i]BACK[/i][/color]"
                on_release: app.root.current = "Intro"
                
                
            IndexButton:
                font_size:100
                text:"[color=0a0a0a][i]A1[/i][/color]"
                
                    
            IndexButton:
                
                text:"[color=0a0a0a][i]Verben[/i][/color]"
                on_release: app.root.current = "Verben"

            IndexButton:
                text:"[color=cd0000][i]LEKTION 1[/i][/color]"
                on_release: app.root.current = "L1"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 2[/i][/color]"
                on_release: app.root.current = "L2"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 3[/i][/color]"
                on_release: app.root.current = "L3"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 4[/i][/color]"
                on_release: app.root.current = "L4"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 5[/i][/color]"
                on_release: app.root.current = "L5"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 6[/i][/color]"
                on_release: app.root.current = "L6"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 7[/i][/color]"
                on_release: app.root.current = "L7"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 8[/i][/color]"
                on_release: app.root.current = "L8"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 9[/i][/color]"
                on_release: app.root.current = "L9"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 10[/i][/color]"
                on_release: app.root.current = "L10"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 11[/i][/color]"
                on_release: app.root.current = "L11"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 12[/i][/color]"
                on_release: app.root.current = "L12"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 13[/i][/color]"
                on_release: app.root.current = "L13"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 14[/i][/color]"
                on_release: app.root.current = "L14"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 15[/i][/color]"
                on_release: app.root.current = "L15"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 16[/i][/color]"
                on_release: app.root.current = "L16"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 17[/i][/color]"
                on_release: app.root.current = "L17"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 18[/i][/color]"
                on_release: app.root.current = "L18"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 19[/i][/color]"
                on_release: app.root.current = "L19"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 20[/i][/color]"
                on_release: app.root.current = "L20"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 21[/i][/color]"
                on_release: app.root.current = "L21"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 22[/i][/color]"
                on_release: app.root.current = "L22"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 23[/i][/color]"
                on_release: app.root.current = "L23"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 24[/i][/color]"
                on_release: app.root.current = "L24"



<VerbosScreen>:
	name: "Verben"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

 
    BoxLayout:
        orientation:'vertical'
        padding:20,20,20,20
        RV:

    
 
 
        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
            
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                    
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9






<L1Screen>:
	name: "L1"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9

            
            
            
<L2Screen>:
	name: "L2"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L3Screen>:
	name: "L3"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L4Screen>:
	name: "L4"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            


            
            
<L5Screen>:
	name: "L5"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L6Screen>:
	name: "L6"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L7Screen>:
	name: "L7"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L8Screen>:
	name: "L8"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L9Screen>:
	name: "L9"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L10Screen>:
	name: "L10"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L11Screen>:
	name: "L11"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L12Screen>:
	name: "L12"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L13Screen>:
	name: "L13"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L14Screen>:
	name: "L14"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L15Screen>:
	name: "L15"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L16Screen>:
	name: "L16"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L17Screen>:
	name: "L17"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L18Screen>:
	name: "L18"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L19Screen>:
	name: "L19"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L20Screen>:
	name: "L20"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L21Screen>:
	name: "L21"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L22Screen>:
	name: "L22"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
<L23Screen>:
	name: "L23"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9
            
            
            
<L24Screen>:
	name: "L24"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size

    
    BoxLayout:
        orientation: "vertical"
    
    
    
        ScrollableLabel:
        
            PageBoxLayout:
                
                orientation: 'horizontal'
                width: root.width
                
                PageLabel:
                    text: '[i]'+root.Al+'[/i]'
                    
                PageLabel:
                    text:'[i]'+root.Es+'[/i]'

                


        FloatLayout:

            size_hint_y: 0.1
            padding: 20,20,20,20
        
            Button:

                text: "[i]Back[/i]"
                on_release: app.root.current = "Index" 
                pos_hint: {"right":0.4, "top":0.95}
                size_hint: 0.3, 0.9

            Button:
                                  
                pos_hint: {"right":0.9, "top":0.95}
                text: "[i]Test[/i]"
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                size_hint: 0.3, 0.9

               


            
  
  
  
<GameScreen>:
	name: "Game"
    
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size
    BoxLayout:

        orientation: "vertical"
        padding: 30,30,30,30
    

        GridLayout:
            
            spacing: '40dp'
            orientation: "vertical"
            size_hint_y: 1
            padding: 30,30,30,30
            
            row_default_height: 60
            cols:1
             

            Label:
                id:btn
                markup: True
                font_size: 70
                text: '[i]Was ist das??[/i]'
                pos_hint: {"right":0.5, "top":0.5}
                color: 1,0.55,0,1
                size_hint: 0.2, 0.1
            
            
            Label:
                id:btn
                markup: True
                font_size: 60
                text: '[i]'+root.test[root.randnum[root.num]]+'[/i]'
                pos_hint: {"right":0.5, "top":0.5}
                color: 1,0.55,0,1
                size_hint: 0.2, 0.1
           
            
               
            GameButton:
                id: btn0
                text: '[i]'+root.solution[root.randnum[0]]+'[/i]'
                on_release: root.on_click0()
                

            GameButton:
                id: btn1
                text: '[i]'+root.solution[root.randnum[1]]+'[/i]'
                on_release: root.on_click1()
                
            GameButton:
                id: btn2
                text: '[i]'+root.solution[root.randnum[2]]+'[/i]'
                on_release: root.on_click2()
                
                
            GameButton:
                id: btn3
                text: '[i]'+root.solution[root.randnum[3]]+'[/i]'
                on_release: root.on_click3()
                
  
            GridLayout:
                
                spacing: '40dp'
                orientation: "vertical"
                size_hint_y: 1
                padding: 30,30,30,30
                
                row_default_height: 60
                cols:2
            


                Button:
                    markup: True
                    font_size: 70
                    text: "[color=1874cd][i]Back[/i][/color]"
                    background_normal: ''
                    background_color: 1, 1, 1, 1
                    
                    on_release:
                        app.root.current = root.manager.SCREEN
                    pos_hint: {"right":0.5, "top":0.1}


                Button:

                    markup: True
                    font_size: 70

                    text: '[color=1874cd][i]Next[/i][/color]'
                    background_normal: ''
                    background_color: 1, 1, 1, 1
         
                    
                    on_release: root.refres()
                    pos_hint: {"right":5, "top":0.1}
            
            
            

  
    
      
            
            ''')



#store.get('LEKTION 24')['Al']
        



class MainApp(App):
    
    
    
    
    def build(self):
        
        self.icon = 'icon.png'
        return presentation


if __name__ == "__main__":
    MainApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Giacomo\.kivy\logs\kivy_20-03-11_82.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.2.0
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "C:\Users\Giacomo\Anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Giacomo\Anaconda3\python.exe"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-8fabeece3aca> in <module>
#      16 from kivy.uix.recycleview import RecycleView
#      17 from kivy.uix.button import Button
# ---> 18 from gtts import gTTs
#      19
#      20
#
# ImportError: cannot import name 'gTTs' from 'gtts' (C:\Users\Giacomo\Anaconda3\lib\site-packages\gtts\__init__.py)
# [INFO   ] [AudioGstplayer] Using Gstreamer 1.16.2.0
# [INFO   ] [Audio       ] Providers: audio_gstplayer, audio_sdl2 (audio_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.5.0 NVIDIA 385.08'>
# [INFO   ] [GL          ] OpenGL vendor <b'NVIDIA Corporation'>
# [INFO   ] [GL          ] OpenGL renderer <b'Quadro K3000M/PCIe/SSE2'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 5
# [INFO   ] [GL          ] Shading version <b'4.50 NVIDIA'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [WARNING] Deprecated property "<AliasProperty name=filename>" of object "<kivy.core.audio.audio_gstplayer.SoundGstplayer object at 0x000002913F7BA278>" was accessed, it will be removed in a future version
# [INFO   ] [Base        ] Leaving application in progress...

# %%
#texttospeech version
import random
from kivy.storage.jsonstore import JsonStore
from kivy.uix.boxlayout import BoxLayout
from kivy.app import App
#kivy.require("1.9.0")
from kivy.lang import Builder
from kivy.uix.screenmanager import ScreenManager, Screen, FadeTransition
from kivy.uix.widget import Widget
from kivy.graphics import Line
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.uix.scrollview import ScrollView 
from kivy.properties import StringProperty 
from kivy.properties import ObjectProperty 
from kivy.uix.recycleview import RecycleView
from kivy.uix.button import Button
from gtts import gTTS 
from kivy.core.audio import SoundLoader 
#import webbrowser






class IntroScreen(Screen):
    pass                           

class IndexScreen(Screen):
    pass
    

class L1Screen(Screen):
    def __init__(self, **kwargs):
        super(L1Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 1')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 1')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    
class L2Screen(Screen):
    def __init__(self, **kwargs):
        super(L2Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 2')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 2')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    
class L3Screen(Screen):
    def __init__(self, **kwargs):
        super(L3Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 3')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 3')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    
    
class L4Screen(Screen):
    def __init__(self, **kwargs):
        super(L4Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 4')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 4')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
        

class L5Screen(Screen):
    def __init__(self, **kwargs):
        super(L5Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 5')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 5')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '5'
        ScreenManagement.SCREEN = 'L5'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L6Screen(Screen):
    def __init__(self, **kwargs):
        super(L6Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 6')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 6')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '6'
        ScreenManagement.SCREEN = 'L6'

    
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L7Screen(Screen):
    def __init__(self, **kwargs):
        super(L7Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 7')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 7')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '7'
        ScreenManagement.SCREEN = 'L7'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L8Screen(Screen):
    def __init__(self, **kwargs):
        super(L8Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 8')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 8')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '8'
        ScreenManagement.SCREEN = 'L8'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L9Screen(Screen):
    def __init__(self, **kwargs):
        super(L9Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 9')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 9')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '9'
        ScreenManagement.SCREEN = 'L9'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L10Screen(Screen):
    def __init__(self, **kwargs):
        super(L10Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 10')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 10')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '10'
        ScreenManagement.SCREEN = 'L10'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L11Screen(Screen):
    def __init__(self, **kwargs):
        super(L11Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 11')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 11')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '11'
        ScreenManagement.SCREEN = 'L11'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L12Screen(Screen):
    def __init__(self, **kwargs):
        super(L12Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 12')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 12')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '12'
        ScreenManagement.SCREEN = 'L12'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L13Screen(Screen):
    def __init__(self, **kwargs):
        super(L13Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 13')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 13')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '13'
        ScreenManagement.SCREEN = 'L13'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L14Screen(Screen):
    def __init__(self, **kwargs):
        super(L14Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 14')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 14')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '14'
        ScreenManagement.SCREEN = 'L14'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L15Screen(Screen):
    def __init__(self, **kwargs):
        super(L15Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 15')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 15')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '15'
        ScreenManagement.SCREEN = 'L15'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L16Screen(Screen):
    def __init__(self, **kwargs):
        super(L16Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 16')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 16')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '16'
        ScreenManagement.SCREEN = 'L16'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L17Screen(Screen):
    def __init__(self, **kwargs):
        super(L17Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 17')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 17')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '17'
        ScreenManagement.SCREEN = 'L17'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L18Screen(Screen):
    def __init__(self, **kwargs):
        super(L18Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 18')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 18')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '18'
        ScreenManagement.SCREEN = 'L18'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L19Screen(Screen):
    def __init__(self, **kwargs):
        super(L19Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 19')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 19')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '19'
        ScreenManagement.SCREEN = 'L19'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L20Screen(Screen):
    def __init__(self, **kwargs):
        super(L20Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 20')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 20')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '20'
        ScreenManagement.SCREEN = 'L20'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L21Screen(Screen):
    def __init__(self, **kwargs):
        super(L21Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 21')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 21')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '21'
        ScreenManagement.SCREEN = 'L21'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L22Screen(Screen):
    def __init__(self, **kwargs):
        super(L22Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 22')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 22')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '22'
        ScreenManagement.SCREEN = 'L22'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L23Screen(Screen):
    def __init__(self, **kwargs):
        super(L23Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 23')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 23')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '23'
        ScreenManagement.SCREEN = 'L23'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L24Screen(Screen):
    def __init__(self, **kwargs):
        super(L24Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 24')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 24')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '24'
        ScreenManagement.SCREEN = 'L24'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass
 
class VerbenScreen(Screen):
    def __init__(self, **kwargs):
        super(VerbenScreen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION Verben')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION Verben')['Es'].split('\n\n')

    def change(self):
        ScreenManagement.MY_GLOBAL = 'Verben'
        ScreenManagement.SCREEN = 'Verben'
        ScreenManagement.control = '1'

    def bck(self):

        ScreenManagement.control = '0'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass


class GameScreen(Screen):
    def __init__(self, **kwargs):
        super(GameScreen, self).__init__(**kwargs)
        App.get_running_app()
        
        self.num = random.choice(range(4))
        self.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.randnum = random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution)))
        
    
    
    def on_click0(self):
        try:
            if self.solution.index(self.ids.btn0.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn0.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn0.background_normal = 'normal.png'
                self.ids.btn0.background_down = 'down.png'
            else:
                self.ids.btn0.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn0.text = self.ids.btn0.text
            
    def on_click1(self):
        try:
            if self.solution.index(self.ids.btn1.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn1.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn1.background_normal = 'normal.png'
                self.ids.btn1.background_down = 'down.png'
            else:
                self.ids.btn1.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn1.text = self.ids.btn1.text
            
    def on_click2(self):
        try:
            if self.solution.index(self.ids.btn2.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn2.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn2.background_normal = 'normal.png'
                self.ids.btn2.background_down = 'down.png'
            else:
                self.ids.btn2.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn2.text = self.ids.btn2.text
            
    def on_click3(self):
        try:
            if self.solution.index(self.ids.btn3.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn3.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn3.background_normal = 'normal.png'
                self.ids.btn3.background_down = 'down.png'
            else:
                self.ids.btn3.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn3.text = self.ids.btn3.text
            
    def refres(self):
        self.num = random.choice(range(4))
        self.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.randnum = random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution)))
        self.ids.btn.text = '[i]'+self.test[self.randnum[self.num]]+'[/i]'
        self.ids.btn0.text = '[i]'+self.solution[self.randnum[0]]+'[/i]'
        self.ids.btn1.text = '[i]'+self.solution[self.randnum[1]]+'[/i]'
        self.ids.btn2.text = '[i]'+self.solution[self.randnum[2]]+'[/i]'
        self.ids.btn3.text = '[i]'+self.solution[self.randnum[3]]+'[/i]'
        self.ids.btn3.background_normal = 'down.png'
        self.ids.btn3.background_down = 'normal.png'
        self.ids.btn2.background_normal = 'down.png'
        self.ids.btn2.background_down = 'normal.png'
        self.ids.btn1.background_normal = 'down.png'
        self.ids.btn1.background_down = 'normal.png'
        self.ids.btn0.background_normal = 'down.png'
        self.ids.btn0.background_down = 'normal.png'

        
        
class MyButton(Button):
    def __init__(self,**kwargs):
        super(MyButton,self).__init__(**kwargs)
        self.markup = True
        self.background_normal = ''
        self.background_color = [1, 1, 1, 1]
        self.color = [0,0,0,1]

    
   # def on_click(self):
        '''
        if ScreenManagement.control == '0':
        
            webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e',''))
        else:
            webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e','').split()[0])
        '''
    def on_click(self):
        
        language = 'de'
        myobj = gTTS(text=self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e',''), lang=language, slow=False)
        myobj.save("welcome.wav") 
        sound = SoundLoader.load('welcome.wav')
        sound.play() 
        #print(sound.length)

        pass
    
    def on_click_release(self):
        #self.background_color = [0, 0, 1, 1]
        
        pass





        

    
#store = JsonStore('A1deutsch.json')
class ScreenManagement(ScreenManager):
    MY_GLOBAL = '1'
    SCREEN = ''
    control = '0'

    pass

        

    
presentation = Builder.load_string('''
#: import FadeTransition kivy.uix.screenmanager.FadeTransition
#:import webbrowser webbrowser


<MyButton>:
    on_press: 
        self.on_click()
        #webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e',''))
        #print(self.state)
<IndexButton@Button>:

    markup: True
    background_normal: ''
    background_color: 1, 1, 1, 1
    font_size: 50



<BoxLayoutPage@BoxLayout>:
    padding:20,20,20,20
    orientation:'vertical'
    canvas.before:
        Color:
            rgba: 1, 0.55, 0, 1
        Rectangle:
            pos: self.pos
            size: self.size
            
<RecycleView>:
    viewclass: 'MyButton'
    RecycleGridLayout:
        cols:2
        default_size_hint: 1, None
        size_hint: 1,None
        height: self.minimum_height
        row_default_height: 110 
        
        
        
        
   
<ButtonBack@Button>:
    text: "[i]Back[/i]"
    pos_hint: {"right":0.4, "top":0.95}
    color:0,0,0,1
    background_normal :''
    background_color :[1, 0.55, 0, 1]
    size_hint: 0.3, 0.9
    markup: True
    font_size: 60

<ButtonTest@Button>:                   
    pos_hint: {"right":0.9, "top":0.95}
    text: "[i]Test[/i]"
    color:0,0,0,1
    background_normal :''
    background_color :[1, 0.55, 0, 1]
    size_hint: 0.3, 0.9
    markup: True
    font_size: 60
  
            
<GameButton@Button>:
    
    font_size: 60
	color: 0,0,0,1
    markup: True
	size_hint: 0.2, 0.1
    background_down: 'normal.png'
    background_normal: 'down.png'
    border: 30,30,30,30


        

    
ScreenManagement:
    transition: FadeTransition()
    IntroScreen:
    IndexScreen:
    L1Screen:
    L2Screen:
    L3Screen:
    L4Screen:
    L5Screen:
    L6Screen:
    L7Screen:
    L8Screen:
    L9Screen:
    L10Screen:
    L11Screen:
    L12Screen:
    L13Screen:
    L14Screen:
    L15Screen:
    L16Screen:
    L17Screen:
    L18Screen:
    L19Screen:
    L20Screen:
    L21Screen:
    L22Screen:
    L23Screen:
    L24Screen:
    VerbenScreen:
    GameScreen:


<IntroScreen>:
	name: "Intro"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size
            
	FloatLayout:
		Button:   
            font_size: 50
            color: 0,0,0,1
            size_hint: 0.2, 0.1
            markup: True
            background_down: 'normal.png'
            background_normal: 'down.png'
            border: 30,30,30,30
            pos_hint: {"right":1, "top":0.1}
			text: "[i]Start[/i]"
			on_release: app.root.current = "Index" 

                        
		Label:
            font_size: 180
            markup: True
			text: "[i]     C2\\nDeutsch\\n     A1[/i]"
			pos_hint: {"right":0.65, "top":0.65}
	        color: 1,0.55,0,1
            size_hint: 0.3, 0.3
            
            
<IndexScreen>:
	name: "Index"
    canvas.before:
        Color:
            rgba: 1, 0.55, 0, 1
        Rectangle:
            pos: self.pos
            size: self.size
    BoxLayout:
        orientation: "vertical"
    

        GridLayout:
            orientation: "vertical"
            size_hint_y: 1
            padding: 20,20,20,20
            height: self.minimum_height\n
            row_default_height: 60
            cols:3
            
                
            IndexButton:
                
                text:"[color=1874cd][i]BACK[/i][/color]"
                on_release: 
                    app.root.current = "Intro"

                
                
            IndexButton:
                font_size:100
                text:"[color=0a0a0a][i]A1[/i][/color]"
                
                    
            IndexButton:
                
                text:"[color=0a0a0a][i]Verben[/i][/color]"
                on_release: app.root.current = "Verben"

            IndexButton:
                text:"[color=cd0000][i]LEKTION 1[/i][/color]"
                on_release: app.root.current = "L1"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 2[/i][/color]"
                on_release: app.root.current = "L2"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 3[/i][/color]"
                on_release: app.root.current = "L3"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 4[/i][/color]"
                on_release: 
                    app.root.current = "L4"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 5[/i][/color]"
                on_release: app.root.current = "L5"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 6[/i][/color]"
                on_release: app.root.current = "L6"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 7[/i][/color]"
                on_release: app.root.current = "L7"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 8[/i][/color]"
                on_release: app.root.current = "L8"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 9[/i][/color]"
                on_release: app.root.current = "L9"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 10[/i][/color]"
                on_release: app.root.current = "L10"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 11[/i][/color]"
                on_release: app.root.current = "L11"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 12[/i][/color]"
                on_release: app.root.current = "L12"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 13[/i][/color]"
                on_release: app.root.current = "L13"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 14[/i][/color]"
                on_release: app.root.current = "L14"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 15[/i][/color]"
                on_release: app.root.current = "L15"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 16[/i][/color]"
                on_release: app.root.current = "L16"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 17[/i][/color]"
                on_release: app.root.current = "L17"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 18[/i][/color]"
                on_release: app.root.current = "L18"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 19[/i][/color]"
                on_release: app.root.current = "L19"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 20[/i][/color]"
                on_release: app.root.current = "L20"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 21[/i][/color]"
                on_release: app.root.current = "L21"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 22[/i][/color]"
                on_release: app.root.current = "L22"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 23[/i][/color]"
                on_release: app.root.current = "L23"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 24[/i][/color]"
                on_release: app.root.current = "L24"





<L1Screen>:
	name: "L1"      
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
<L2Screen>:
	name: "L2"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L3Screen>:
	name: "L3"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L4Screen>:
	name: "L4"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L5Screen>:
	name: "L5"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L6Screen>:
	name: "L6"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L7Screen>:
	name: "L7"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L8Screen>:
	name: "L8"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L9Screen>:
	name: "L9"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L10Screen>:
	name: "L10"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L11Screen>:
	name: "L11"


            
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
<L12Screen>:
	name: "L12"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L13Screen>:
	name: "L13"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L14Screen>:
	name: "L14"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L15Screen>:
	name: "L15"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L16Screen>:
	name: "L16"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L17Screen>:
	name: "L17"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L18Screen>:
	name: "L18"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L19Screen>:
	name: "L19"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L20Screen>:
	name: "L20"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L21Screen>:
	name: "L21"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L22Screen>:
	name: "L22"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L23Screen>:
	name: "L23"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L24Screen>:
	name: "L24"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game"
                    
                    
<VerbenScreen>:
	name: "Verben"  
    on_pre_enter: root.change()  
    BoxLayoutPage:
        RecycleView:
            
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]   
            
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: 
                    app.root.current = "Index"
                    root.bck() 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game"

        


  
<GameScreen>:

	name: "Game"
    on_pre_enter: root.refres()
    
    
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size
    BoxLayout:

        orientation: "vertical"
        padding: 30,30,30,30
    

        GridLayout:
            
            spacing: '40dp'
            orientation: "vertical"
            size_hint_y: 1
            padding: 30,30,30,30
            
            row_default_height: 60
            cols:1
             

            Label:
                id:btn
                markup: True
                font_size: 70
                text: '[i]Was ist das??[/i]'
                pos_hint: {"right":0.5, "top":0.5}
                color: 1,0.55,0,1
                size_hint: 0.2, 0.1
            
            
            Label:
                id:btn
                markup: True
                font_size: 60
                text: '[i]'+root.test[root.randnum[root.num]]+'[/i]'
                pos_hint: {"right":0.5, "top":0.5}
                color: 1,0.55,0,1
                size_hint: 0.2, 0.1
           
            
               
            GameButton:
                id: btn0
                text: '[i]'+root.solution[root.randnum[0]]+'[/i]'
                on_release: root.on_click0()
                

            GameButton:
                id: btn1
                text: '[i]'+root.solution[root.randnum[1]]+'[/i]'
                on_release: root.on_click1()
                
            GameButton:
                id: btn2
                text: '[i]'+root.solution[root.randnum[2]]+'[/i]'
                on_release: root.on_click2()
                
                
            GameButton:
                id: btn3
                text: '[i]'+root.solution[root.randnum[3]]+'[/i]'
                on_release: root.on_click3()
                
  
            GridLayout:
                
                spacing: '40dp'
                orientation: "vertical"
                size_hint_y: 1
                padding: 30,30,30,30
                
                row_default_height: 60
                cols:2
            


                Button:
                    markup: True
                    font_size: 70
                    text: "[color=1874cd][i]Back[/i][/color]"
                    background_normal: ''
                    background_color: 1, 1, 1, 1
                    
                    on_release:
                        app.root.current = root.manager.SCREEN
                    pos_hint: {"right":0.5, "top":0.1}


                Button:

                    markup: True
                    font_size: 70

                    text: '[color=1874cd][i]Next[/i][/color]'
                    background_normal: ''
                    background_color: 1, 1, 1, 1
         
                    
                    on_release: root.refres()
                    pos_hint: {"right":5, "top":0.1}

            



        
            ''')



#store.get('LEKTION 24')['Al']
        



class MainApp(App):
    
    
    
    
    def build(self):
        
        self.icon = 'icon.png'

        return presentation


if __name__ == "__main__":
    MainApp().run()
# Out:
# -1
# -1
# -1
# -1

# %%
#json
import random
from kivy.storage.jsonstore import JsonStore
from kivy.uix.boxlayout import BoxLayout
from kivy.app import App
#kivy.require("1.9.0")
from kivy.lang import Builder
from kivy.uix.screenmanager import ScreenManager, Screen, FadeTransition
from kivy.uix.widget import Widget
from kivy.graphics import Line
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.uix.scrollview import ScrollView 
from kivy.properties import StringProperty 
from kivy.properties import ObjectProperty 
from kivy.uix.recycleview import RecycleView
from kivy.uix.button import Button
#from gtts import gTTS 
from kivy.core.audio import SoundLoader 
import webbrowser





class IntroScreen(Screen):
    pass                           

class IndexScreen(Screen):
    pass
    

class L1Screen(Screen):
    def __init__(self, **kwargs):
        super(L1Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 1')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 1')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    
class L2Screen(Screen):
    def __init__(self, **kwargs):
        super(L2Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 2')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 2')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    
class L3Screen(Screen):
    def __init__(self, **kwargs):
        super(L3Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 3')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 3')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    
    
class L4Screen(Screen):
    def __init__(self, **kwargs):
        super(L4Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 4')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 4')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
        
    def change(self):
        ScreenManagement.MY_GLOBAL = '1'
        ScreenManagement.SCREEN = 'L1'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
        

class L5Screen(Screen):
    def __init__(self, **kwargs):
        super(L5Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 5')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 5')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '5'
        ScreenManagement.SCREEN = 'L5'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L6Screen(Screen):
    def __init__(self, **kwargs):
        super(L6Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 6')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 6')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '6'
        ScreenManagement.SCREEN = 'L6'

    
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L7Screen(Screen):
    def __init__(self, **kwargs):
        super(L7Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 7')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 7')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '7'
        ScreenManagement.SCREEN = 'L7'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L8Screen(Screen):
    def __init__(self, **kwargs):
        super(L8Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 8')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 8')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '8'
        ScreenManagement.SCREEN = 'L8'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L9Screen(Screen):
    def __init__(self, **kwargs):
        super(L9Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 9')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 9')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '9'
        ScreenManagement.SCREEN = 'L9'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L10Screen(Screen):
    def __init__(self, **kwargs):
        super(L10Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 10')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 10')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '10'
        ScreenManagement.SCREEN = 'L10'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L11Screen(Screen):
    def __init__(self, **kwargs):
        super(L11Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 11')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 11')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '11'
        ScreenManagement.SCREEN = 'L11'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L12Screen(Screen):
    def __init__(self, **kwargs):
        super(L12Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 12')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 12')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '12'
        ScreenManagement.SCREEN = 'L12'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L13Screen(Screen):
    def __init__(self, **kwargs):
        super(L13Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 13')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 13')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '13'
        ScreenManagement.SCREEN = 'L13'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L14Screen(Screen):
    def __init__(self, **kwargs):
        super(L14Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 14')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 14')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '14'
        ScreenManagement.SCREEN = 'L14'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L15Screen(Screen):
    def __init__(self, **kwargs):
        super(L15Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 15')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 15')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '15'
        ScreenManagement.SCREEN = 'L15'
        
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L16Screen(Screen):
    def __init__(self, **kwargs):
        super(L16Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 16')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 16')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '16'
        ScreenManagement.SCREEN = 'L16'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L17Screen(Screen):
    def __init__(self, **kwargs):
        super(L17Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 17')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 17')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '17'
        ScreenManagement.SCREEN = 'L17'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L18Screen(Screen):
    def __init__(self, **kwargs):
        super(L18Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 18')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 18')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '18'
        ScreenManagement.SCREEN = 'L18'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L19Screen(Screen):
    def __init__(self, **kwargs):
        super(L19Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 19')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 19')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '19'
        ScreenManagement.SCREEN = 'L19'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L20Screen(Screen):
    def __init__(self, **kwargs):
        super(L20Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 20')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 20')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '20'
        ScreenManagement.SCREEN = 'L20'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L21Screen(Screen):
    def __init__(self, **kwargs):
        super(L21Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 21')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 21')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '21'
        ScreenManagement.SCREEN = 'L21'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L22Screen(Screen):
    def __init__(self, **kwargs):
        super(L22Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 22')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 22')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '22'
        ScreenManagement.SCREEN = 'L22'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L23Screen(Screen):
    def __init__(self, **kwargs):
        super(L23Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 23')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 23')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '23'
        ScreenManagement.SCREEN = 'L23'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass

class L24Screen(Screen):
    def __init__(self, **kwargs):
        super(L24Screen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION 24')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION 24')['Es'].split('\n\n')
        #Clock.schedule_once(lambda *args: self.load())
    def change(self):
        ScreenManagement.MY_GLOBAL = '24'
        ScreenManagement.SCREEN = 'L24'
        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass
 
class VerbenScreen(Screen):
    def __init__(self, **kwargs):
        super(VerbenScreen, self).__init__(**kwargs)
        self.Al = JsonStore("A1deutsch.json").get('LEKTION Verben')['Al'].split('\n\n')
        self.Es = JsonStore("A1deutsch.json").get('LEKTION Verben')['Es'].split('\n\n')

    def change(self):
        ScreenManagement.MY_GLOBAL = 'Verben'
        ScreenManagement.SCREEN = 'Verben'
        ScreenManagement.control = '1'

    def bck(self):

        ScreenManagement.control = '0'

        
    def test(self):
        lista = []
        j = 0
        try:
            for i in self.Al:
                lista.append(i)
                lista.append(self.Es[j])
                j +=1
        except:
            return lista
        return lista
    pass


class GameScreen(Screen):
    def __init__(self, **kwargs):
        super(GameScreen, self).__init__(**kwargs)
        App.get_running_app()
        
        self.num = random.choice(range(4))
        self.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.randnum = random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution)))
        
    
    
    def on_click0(self):
        try:
            if self.solution.index(self.ids.btn0.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn0.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn0.background_normal = 'normal.png'
                self.ids.btn0.background_down = 'down.png'
            else:
                self.ids.btn0.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn0.text = self.ids.btn0.text
            
    def on_click1(self):
        try:
            if self.solution.index(self.ids.btn1.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn1.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn1.background_normal = 'normal.png'
                self.ids.btn1.background_down = 'down.png'
            else:
                self.ids.btn1.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn1.text = self.ids.btn1.text
            
    def on_click2(self):
        try:
            if self.solution.index(self.ids.btn2.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn2.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn2.background_normal = 'normal.png'
                self.ids.btn2.background_down = 'down.png'
            else:
                self.ids.btn2.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn2.text = self.ids.btn2.text
            
    def on_click3(self):
        try:
            if self.solution.index(self.ids.btn3.text.replace('[i]','').replace('[/i]','')) == self.test.index(self.ids.btn.text.replace('[i]','').replace('[/i]','')):
                self.ids.btn3.text = '[color=006400][i]Sehr gut[/i][/color]!!'
                self.ids.btn3.background_normal = 'normal.png'
                self.ids.btn3.background_down = 'down.png'
            else:
                self.ids.btn3.text = '[color=cd0000][i]Sehr schlecht[/i][/color]!'
        except:
            self.ids.btn3.text = self.ids.btn3.text
            
    def refres(self):
        self.num = random.choice(range(4))
        self.solution = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Es'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.test = JsonStore("A1deutsch.json").get('LEKTION '+ScreenManagement.MY_GLOBAL)['Al'].replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace('\n\n\n','\n\n').split('\n\n')
        self.randnum = random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution))),random.choice(range(len(self.solution)))
        self.ids.btn.text = '[i]'+self.test[self.randnum[self.num]]+'[/i]'
        self.ids.btn0.text = '[i]'+self.solution[self.randnum[0]]+'[/i]'
        self.ids.btn1.text = '[i]'+self.solution[self.randnum[1]]+'[/i]'
        self.ids.btn2.text = '[i]'+self.solution[self.randnum[2]]+'[/i]'
        self.ids.btn3.text = '[i]'+self.solution[self.randnum[3]]+'[/i]'
        self.ids.btn3.background_normal = 'down.png'
        self.ids.btn3.background_down = 'normal.png'
        self.ids.btn2.background_normal = 'down.png'
        self.ids.btn2.background_down = 'normal.png'
        self.ids.btn1.background_normal = 'down.png'
        self.ids.btn1.background_down = 'normal.png'
        self.ids.btn0.background_normal = 'down.png'
        self.ids.btn0.background_down = 'normal.png'

        
        
class MyButton(Button):
    def __init__(self,**kwargs):
        super(MyButton,self).__init__(**kwargs)
        self.markup = True
        self.background_normal = ''
        self.background_color = [1, 1, 1, 1]
        self.color = [0,0,0,1]

    
    def on_click(self):
        if ScreenManagement.control == '0':
        
            webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e',''))
        else:
            webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e','').split()[0])

       




       
        
        

        #on_release: webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e',''))
        #self.sound = SoundLoader.load('welcome.wav') 
        #if self.sound is None:
            #print('problema1')
            #self.sound = SoundLoader.load('welcome.wav')
        #else:
           # print('problema2')
            #self.sound = SoundLoader.load('welcome.wav')
        #self.sound.play()
        
        #language = 'de'.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e','')
        #myobj = gTTS(text=self.text, lang=language, slow=False)
        #myobj.save("welcome.wav") 
        #sound = SoundLoader.load('welcome.wav')
        #sound.play() 
        #print(sound.length)
        pass
    
    def on_click_release(self):
        #self.background_color = [0, 0, 1, 1]
        
        pass





        

    
#store = JsonStore('A1deutsch.json')
class ScreenManagement(ScreenManager):
    MY_GLOBAL = '1'
    SCREEN = ''
    control = '0'

    pass

        

    
presentation = Builder.load_string('''
#: import FadeTransition kivy.uix.screenmanager.FadeTransition
#:import webbrowser webbrowser


<MyButton>:
    on_press: 
        self.on_click()
        #webbrowser.open('https://context.reverso.net/traduccion/aleman-espanol/'+self.text.replace('[i]','').replace('[/i]','').replace('[/color]','').replace('[color=27408b]','').replace('[color=cd0000]','').replace(' -n','').replace(' -s','').replace(' -en','').replace(' -..e','').replace(' -e',''))
        #print(self.state)
<IndexButton@Button>:

    markup: True
    background_normal: ''
    background_color: 1, 1, 1, 1
    font_size: 50



<BoxLayoutPage@BoxLayout>:
    padding:20,20,20,20
    orientation:'vertical'
    canvas.before:
        Color:
            rgba: 1, 0.55, 0, 1
        Rectangle:
            pos: self.pos
            size: self.size
            
<RecycleView>:
    viewclass: 'MyButton'
    RecycleGridLayout:
        cols:2
        default_size_hint: 1, None
        size_hint: 1,None
        height: self.minimum_height
        row_default_height: 110 
        
        
        
        
   
<ButtonBack@Button>:
    text: "[i]Back[/i]"
    pos_hint: {"right":0.4, "top":0.95}
    color:0,0,0,1
    background_normal :''
    background_color :[1, 0.55, 0, 1]
    size_hint: 0.3, 0.9
    markup: True
    font_size: 60

<ButtonTest@Button>:                   
    pos_hint: {"right":0.9, "top":0.95}
    text: "[i]Test[/i]"
    color:0,0,0,1
    background_normal :''
    background_color :[1, 0.55, 0, 1]
    size_hint: 0.3, 0.9
    markup: True
    font_size: 60
  
            
<GameButton@Button>:
    
    font_size: 60
	color: 0,0,0,1
    markup: True
	size_hint: 0.2, 0.1
    background_down: 'normal.png'
    background_normal: 'down.png'
    border: 30,30,30,30


        

    
ScreenManagement:
    transition: FadeTransition()
    IntroScreen:
    IndexScreen:
    L1Screen:
    L2Screen:
    L3Screen:
    L4Screen:
    L5Screen:
    L6Screen:
    L7Screen:
    L8Screen:
    L9Screen:
    L10Screen:
    L11Screen:
    L12Screen:
    L13Screen:
    L14Screen:
    L15Screen:
    L16Screen:
    L17Screen:
    L18Screen:
    L19Screen:
    L20Screen:
    L21Screen:
    L22Screen:
    L23Screen:
    L24Screen:
    VerbenScreen:
    GameScreen:


<IntroScreen>:
	name: "Intro"
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size
            
	FloatLayout:
		Button:   
            font_size: 50
            color: 0,0,0,1
            size_hint: 0.2, 0.1
            markup: True
            background_down: 'normal.png'
            background_normal: 'down.png'
            border: 30,30,30,30
            pos_hint: {"right":1, "top":0.1}
			text: "[i]Start[/i]"
			on_release: app.root.current = "Index" 

                        
		Label:
            font_size: 180
            markup: True
			text: "[i]     C2\\nDeutsch\\n     A1[/i]"
			pos_hint: {"right":0.65, "top":0.65}
	        color: 1,0.55,0,1
            size_hint: 0.3, 0.3
            
            
<IndexScreen>:
	name: "Index"
    canvas.before:
        Color:
            rgba: 1, 0.55, 0, 1
        Rectangle:
            pos: self.pos
            size: self.size
    BoxLayout:
        orientation: "vertical"
    

        GridLayout:
            orientation: "vertical"
            size_hint_y: 1
            padding: 20,20,20,20
            height: self.minimum_height\n
            row_default_height: 60
            cols:3
            
                
            IndexButton:
                
                text:"[color=1874cd][i]BACK[/i][/color]"
                on_release: 
                    app.root.current = "Intro"

                
                
            IndexButton:
                font_size:100
                text:"[color=0a0a0a][i]A1[/i][/color]"
                
                    
            IndexButton:
                
                text:"[color=0a0a0a][i]Verben[/i][/color]"
                on_release: app.root.current = "Verben"

            IndexButton:
                text:"[color=cd0000][i]LEKTION 1[/i][/color]"
                on_release: app.root.current = "L1"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 2[/i][/color]"
                on_release: app.root.current = "L2"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 3[/i][/color]"
                on_release: app.root.current = "L3"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 4[/i][/color]"
                on_release: 
                    app.root.current = "L4"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 5[/i][/color]"
                on_release: app.root.current = "L5"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 6[/i][/color]"
                on_release: app.root.current = "L6"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 7[/i][/color]"
                on_release: app.root.current = "L7"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 8[/i][/color]"
                on_release: app.root.current = "L8"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 9[/i][/color]"
                on_release: app.root.current = "L9"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 10[/i][/color]"
                on_release: app.root.current = "L10"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 11[/i][/color]"
                on_release: app.root.current = "L11"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 12[/i][/color]"
                on_release: app.root.current = "L12"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 13[/i][/color]"
                on_release: app.root.current = "L13"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 14[/i][/color]"
                on_release: app.root.current = "L14"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 15[/i][/color]"
                on_release: app.root.current = "L15"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 16[/i][/color]"
                on_release: app.root.current = "L16"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 17[/i][/color]"
                on_release: app.root.current = "L17"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 18[/i][/color]"
                on_release: app.root.current = "L18"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 19[/i][/color]"
                on_release: app.root.current = "L19"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 20[/i][/color]"
                on_release: app.root.current = "L20"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 21[/i][/color]"
                on_release: app.root.current = "L21"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 22[/i][/color]"
                on_release: app.root.current = "L22"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 23[/i][/color]"
                on_release: app.root.current = "L23"
            IndexButton:
                text:"[color=cd0000][i]LEKTION 24[/i][/color]"
                on_release: app.root.current = "L24"





<L1Screen>:
	name: "L1"      
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
<L2Screen>:
	name: "L2"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L3Screen>:
	name: "L3"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L4Screen>:
	name: "L4"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L5Screen>:
	name: "L5"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L6Screen>:
	name: "L6"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L7Screen>:
	name: "L7"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L8Screen>:
	name: "L8"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L9Screen>:
	name: "L9"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L10Screen>:
	name: "L10"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L11Screen>:
	name: "L11"


            
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
<L12Screen>:
	name: "L12"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L13Screen>:
	name: "L13"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L14Screen>:
	name: "L14"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L15Screen>:
	name: "L15"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L16Screen>:
	name: "L16"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L17Screen>:
	name: "L17"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L18Screen>:
	name: "L18"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L19Screen>:
	name: "L19"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L20Screen>:
	name: "L20"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L21Screen>:
	name: "L21"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
<L22Screen>:
	name: "L22"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L23Screen>:
	name: "L23"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game" 
                    
                    
                    
<L24Screen>:
	name: "L24"     
    BoxLayoutPage:
        RecycleView:
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]    
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: app.root.current = "Index" 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game"
                    
                    
<VerbenScreen>:
	name: "Verben"  
    on_pre_enter: root.change()  
    BoxLayoutPage:
        RecycleView:
            
            data:[{'text': str('[i]'+x+'[/i]')} for x in root.test()]   
            
        FloatLayout:    
            size_hint_y: 0.1
            padding: 20,20,20,20
            ButtonBack:
                on_release: 
                    app.root.current = "Index"
                    root.bck() 
            ButtonTest:
                on_press:root.change()
                on_release:
                    app.root.current = "Game"

        


  
<GameScreen>:

	name: "Game"
    on_pre_enter: root.refres()
    
    
    canvas.before:
        Color:
            rgba: 1, 1, 1, 1
        Rectangle:
            pos: self.pos
            size: self.size
    BoxLayout:

        orientation: "vertical"
        padding: 30,30,30,30
    

        GridLayout:
            
            spacing: '40dp'
            orientation: "vertical"
            size_hint_y: 1
            padding: 30,30,30,30
            
            row_default_height: 60
            cols:1
             

            Label:
                id:btn
                markup: True
                font_size: 70
                text: '[i]Was ist das??[/i]'
                pos_hint: {"right":0.5, "top":0.5}
                color: 1,0.55,0,1
                size_hint: 0.2, 0.1
            
            
            Label:
                id:btn
                markup: True
                font_size: 60
                text: '[i]'+root.test[root.randnum[root.num]]+'[/i]'
                pos_hint: {"right":0.5, "top":0.5}
                color: 1,0.55,0,1
                size_hint: 0.2, 0.1
           
            
               
            GameButton:
                id: btn0
                text: '[i]'+root.solution[root.randnum[0]]+'[/i]'
                on_release: root.on_click0()
                

            GameButton:
                id: btn1
                text: '[i]'+root.solution[root.randnum[1]]+'[/i]'
                on_release: root.on_click1()
                
            GameButton:
                id: btn2
                text: '[i]'+root.solution[root.randnum[2]]+'[/i]'
                on_release: root.on_click2()
                
                
            GameButton:
                id: btn3
                text: '[i]'+root.solution[root.randnum[3]]+'[/i]'
                on_release: root.on_click3()
                
  
            GridLayout:
                
                spacing: '40dp'
                orientation: "vertical"
                size_hint_y: 1
                padding: 30,30,30,30
                
                row_default_height: 60
                cols:2
            


                Button:
                    markup: True
                    font_size: 70
                    text: "[color=1874cd][i]Back[/i][/color]"
                    background_normal: ''
                    background_color: 1, 1, 1, 1
                    
                    on_release:
                        app.root.current = root.manager.SCREEN
                    pos_hint: {"right":0.5, "top":0.1}


                Button:

                    markup: True
                    font_size: 70

                    text: '[color=1874cd][i]Next[/i][/color]'
                    background_normal: ''
                    background_color: 1, 1, 1, 1
         
                    
                    on_release: root.refres()
                    pos_hint: {"right":5, "top":0.1}

            



        
            ''')



#store.get('LEKTION 24')['Al']
        



class MainApp(App):
    
    
    
    
    def build(self):
        
        self.icon = 'icon.png'

        return presentation


if __name__ == "__main__":
    MainApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\Giacomo\.kivy\logs\kivy_20-03-11_83.txt
# [INFO   ] [deps        ] Successfully imported "kivy_deps.gstreamer" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.angle" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.glew" 0.2.0
# [INFO   ] [deps        ] Successfully imported "kivy_deps.sdl2" 0.2.0
# [INFO   ] [Kivy        ] v1.11.1
# [INFO   ] [Kivy        ] Installed at "C:\Users\Giacomo\Anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.4 (default, Aug  9 2019, 18:34:13) [MSC v.1915 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\Giacomo\Anaconda3\python.exe"
# [INFO   ] [Factory     ] 184 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil, img_gif (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [AudioGstplayer] Using Gstreamer 1.16.2.0
# [INFO   ] [Audio       ] Providers: audio_gstplayer, audio_sdl2 (audio_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.5.0 NVIDIA 385.08'>
# [INFO   ] [GL          ] OpenGL vendor <b'NVIDIA Corporation'>
# [INFO   ] [GL          ] OpenGL renderer <b'Quadro K3000M/PCIe/SSE2'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 5
# [INFO   ] [GL          ] Shading version <b'4.50 NVIDIA'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...
# [INFO   ] [WindowSDL   ] exiting mainloop and closing.
